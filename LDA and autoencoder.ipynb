# %% [markdown]
# <a href="https://colab.research.google.com/github/Khaled-Mohammed-Abdelgaber/PPG_Clustering/blob/main/LDA%20and%20autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
ppg_one_beat = pd.read_csv("/content/gdrive/MyDrive/data/peak2peak_aug_2022/Part_1/p2p_beats/part_1_PPG_beats_P2P_Aug_2022.csv",
                           names = np.arange(120))
ppg_10_beats = pd.read_csv("/content/gdrive/MyDrive/data/peak2peak_aug_2022/Part_1/10_beat_signals/part_1_PPG_signals_10_beats_Aug_2022.csv",
                           names = np.arange(1024))
id = pd.read_csv("/content/gdrive/MyDrive/data/peak2peak_aug_2022/Part_1/p2p_beats/part_1_Subj_ID_beats_P2P_Aug_2022.csv",names = ["ID"])
sys_df = pd.read_csv("/content/gdrive/MyDrive/data/peak2peak_aug_2022/Part_1/p2p_beats/part_1_SYS_BP_beats_P2P_Aug_2022.csv",
                     names = ["sys"])
dia_df = pd.read_csv("/content/gdrive/MyDrive/data/peak2peak_aug_2022/Part_1/p2p_beats/part_1_Dia_BP_beats_P2P_Aug_2022.csv",
                     names = ["dia"])

# %%
df_info = pd.DataFrame()
 
df_info["dia"]  = dia_df
df_info["sys"]  = sys_df
df_info["ID"] = id

# %%
X = ppg_one_beat.values

# %%
y = df_info["sys"].values

# %%
type(y)
# Out:
# numpy.ndarray

# %%
for i in range(len(y)):
  if y[i] < 80:
    y[i] = 0
  elif y[i] < 90:
    y[i] = 1
  elif y[i] < 100:
    y[i] = 2
  elif y[i] < 110:
    y[i] = 3
  elif y[i] < 120:
    y[i] = 4 
  elif y[i] < 130:
    y[i] = 5
  elif y[i] < 140:
    y[i] = 6
  elif y[i] < 150:
    y[i] = 7
  elif y[i] < 160:
    y[i] = 8
  elif y[i] < 170:
    y[i] = 9
  elif y[i] < 180:
    y[i] = 10
  elif y[i] < 190:
    y[i] = 11
  else:
    y[i] = 12

# %%
y
# Out:
# array([5., 5., 4., ..., 1., 1., 1.])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
colors = ['royalblue','red','deeppink', 'maroon', 'mediumorchid', 'tan', 'forestgreen', 'olive', 'goldenrod', 'lightcyan', 'navy']
vectorizer = np.vectorize(lambda x: colors[x % len(colors)])

# %%
lda = LinearDiscriminantAnalysis(n_components=12)
X_lda_comp = lda.fit(X, y).transform(X)

# %%
lda.explained_variance_ratio_
# Out:
# array([0.51752546, 0.16698827, 0.1229704 , 0.06028748, 0.05000757,
#        0.02965918, 0.01789165, 0.01304061, 0.00952329, 0.00719488,
#        0.00278347, 0.00212774])

# %%
X_lda_comp.shape
# Out:
# (154540, 12)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt


 
# initialise kmeans
kmeans = KMeans(n_clusters=12)
kmeans.fit(X_lda_comp)
cluster_labels = kmeans.labels_

# %%
cluster_labels
# Out:
# array([11, 11, 11, ...,  5,  5,  5], dtype=int32)

# %%
for i in range(12):
  plt.figure(i);
  plt.plot(ppg_one_beat[cluster_labels == i].values[:100].T,alpha = 0.5);

# %%
ppg_one_beat[cluster_labels == 1].values[:].shape
# Out:
# (20344, 120)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import load_model

# %%
X.shape[0]*0.75
# Out:
# 115905.0

# %%
X_train = X[:115905,:]
X_test = X[115905:,:]

# %%
X_train.shape
# Out:
# (115905, 120)

# %%
# AutoEncoder Model Preparation
n_inputs = X.shape[1]
# define encoder
input_data_shape= Input(shape=(n_inputs,))
# encoder level 1
encoder= Dense(n_inputs)(input_data_shape)
encoder = BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# encoder level 2
encoder= Dense(n_inputs/2)(encoder)
encoder= BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# encoder level 3
encoder= Dense(round(float(n_inputs) / 4))(encoder)
encoder= BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# bottleneck
n_bottleneck = round(float(n_inputs) / 20)
bottleneck = Dense(n_bottleneck)(encoder)

# define decoder, level 1
decoder = Dense(round(float(n_inputs) / 4.0))(bottleneck)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)
# decoder level 2
decoder = Dense(n_inputs/2)(decoder)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)
# decoder level 3
decoder = Dense(n_inputs)(decoder)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)

# %%
# output layer
output = Dense(n_inputs, activation='linear')(decoder)
# define autoencoder model
model = Model(inputs=input_data_shape, outputs=output)
# compile autoencoder model
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 120)]             0
#
#  dense_38 (Dense)            (None, 120)               14520
#
#  batch_normalization_28 (Bat  (None, 120)              480
#  chNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 120)               0
#
#  dense_39 (Dense)            (None, 60)                7260
#
#  batch_normalization_29 (Bat  (None, 60)               240
#  chNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 60)                0
#
#  dense_40 (Dense)            (None, 30)                1830
#
#  batch_normalization_30 (Bat  (None, 30)               120
#  chNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 30)                0
#
#  dense_41 (Dense)            (None, 6)                 186
#
#  dense_42 (Dense)            (None, 30)                210
#
#  batch_normalization_31 (Bat  (None, 30)               120
#  chNormalization)
#
#  leaky_re_lu_31 (LeakyReLU)  (None, 30)                0
#
#  dense_43 (Dense)            (None, 60)                1860
#
#  batch_normalization_32 (Bat  (None, 60)               240
#  chNormalization)
#
#  leaky_re_lu_32 (LeakyReLU)  (None, 60)                0
#
#  dense_44 (Dense)            (None, 120)               7320
#
#  batch_normalization_33 (Bat  (None, 120)              480
#  chNormalization)
#
#  leaky_re_lu_33 (LeakyReLU)  (None, 120)               0
#
#  dense_45 (Dense)            (None, 120)               14520
#
# =================================================================
# Total params: 49,386
# Trainable params: 48,546
# Non-trainable params: 840
# _________________________________________________________________

# %%
history = model.fit(X_train, X_train, epochs=50, batch_size=16, verbose=2, validation_data=(X_test,X_test))
# Out:
# Epoch 1/50
# 7245/7245 - 19s - loss: 0.0044 - val_loss: 0.0021 - 19s/epoch - 3ms/step
# Epoch 2/50
# 7245/7245 - 18s - loss: 0.0015 - val_loss: 0.0017 - 18s/epoch - 2ms/step
# Epoch 3/50
# 7245/7245 - 17s - loss: 0.0011 - val_loss: 0.0013 - 17s/epoch - 2ms/step
# Epoch 4/50
# 7245/7245 - 17s - loss: 9.7455e-04 - val_loss: 8.0036e-04 - 17s/epoch - 2ms/step
# Epoch 5/50
# 7245/7245 - 17s - loss: 8.6742e-04 - val_loss: 7.1233e-04 - 17s/epoch - 2ms/step
# Epoch 6/50
# 7245/7245 - 17s - loss: 7.9071e-04 - val_loss: 5.8264e-04 - 17s/epoch - 2ms/step
# Epoch 7/50
# 7245/7245 - 17s - loss: 7.3567e-04 - val_loss: 5.7777e-04 - 17s/epoch - 2ms/step
# Epoch 8/50
# 7245/7245 - 17s - loss: 7.0481e-04 - val_loss: 5.7427e-04 - 17s/epoch - 2ms/step
# Epoch 9/50
# 7245/7245 - 17s - loss: 6.6996e-04 - val_loss: 7.6821e-04 - 17s/epoch - 2ms/step
# Epoch 10/50
# 7245/7245 - 17s - loss: 6.3509e-04 - val_loss: 6.1920e-04 - 17s/epoch - 2ms/step
# Epoch 11/50
# 7245/7245 - 17s - loss: 6.1196e-04 - val_loss: 5.8117e-04 - 17s/epoch - 2ms/step
# Epoch 12/50
# 7245/7245 - 17s - loss: 5.9562e-04 - val_loss: 5.9207e-04 - 17s/epoch - 2ms/step
# Epoch 13/50
# 7245/7245 - 17s - loss: 5.7519e-04 - val_loss: 6.8401e-04 - 17s/epoch - 2ms/step
# Epoch 14/50
# 7245/7245 - 17s - loss: 5.7115e-04 - val_loss: 6.1051e-04 - 17s/epoch - 2ms/step
# Epoch 15/50
# 7245/7245 - 17s - loss: 5.5381e-04 - val_loss: 5.4450e-04 - 17s/epoch - 2ms/step
# Epoch 16/50
# 7245/7245 - 17s - loss: 5.4215e-04 - val_loss: 6.6285e-04 - 17s/epoch - 2ms/step
# Epoch 17/50
# 7245/7245 - 17s - loss: 5.2947e-04 - val_loss: 5.5319e-04 - 17s/epoch - 2ms/step
# Epoch 18/50
# 7245/7245 - 17s - loss: 5.1924e-04 - val_loss: 5.3614e-04 - 17s/epoch - 2ms/step
# Epoch 19/50
# 7245/7245 - 17s - loss: 5.0976e-04 - val_loss: 5.1970e-04 - 17s/epoch - 2ms/step
# Epoch 20/50
# 7245/7245 - 17s - loss: 5.0993e-04 - val_loss: 5.0563e-04 - 17s/epoch - 2ms/step
# Epoch 21/50
# 7245/7245 - 17s - loss: 5.0053e-04 - val_loss: 4.7572e-04 - 17s/epoch - 2ms/step
# Epoch 22/50
# 7245/7245 - 17s - loss: 4.9739e-04 - val_loss: 0.0010 - 17s/epoch - 2ms/step
# Epoch 23/50
# 7245/7245 - 17s - loss: 4.8539e-04 - val_loss: 6.6212e-04 - 17s/epoch - 2ms/step
# Epoch 24/50
# 7245/7245 - 17s - loss: 4.8246e-04 - val_loss: 5.0840e-04 - 17s/epoch - 2ms/step
# Epoch 25/50
# 7245/7245 - 17s - loss: 4.7671e-04 - val_loss: 5.6968e-04 - 17s/epoch - 2ms/step
# Epoch 26/50
# 7245/7245 - 17s - loss: 4.7085e-04 - val_loss: 5.4848e-04 - 17s/epoch - 2ms/step
# Epoch 27/50
# 7245/7245 - 17s - loss: 4.6904e-04 - val_loss: 4.9228e-04 - 17s/epoch - 2ms/step
# Epoch 28/50
# 7245/7245 - 17s - loss: 4.6612e-04 - val_loss: 5.0008e-04 - 17s/epoch - 2ms/step
# Epoch 29/50
# 7245/7245 - 17s - loss: 4.5525e-04 - val_loss: 4.8838e-04 - 17s/epoch - 2ms/step
# Epoch 30/50
# 7245/7245 - 17s - loss: 4.5100e-04 - val_loss: 5.0541e-04 - 17s/epoch - 2ms/step
# Epoch 31/50
# 7245/7245 - 17s - loss: 4.5496e-04 - val_loss: 4.7740e-04 - 17s/epoch - 2ms/step
# Epoch 32/50
# 7245/7245 - 17s - loss: 4.5007e-04 - val_loss: 6.0619e-04 - 17s/epoch - 2ms/step
# Epoch 33/50
# 7245/7245 - 17s - loss: 4.4424e-04 - val_loss: 5.2651e-04 - 17s/epoch - 2ms/step
# Epoch 34/50
# 7245/7245 - 17s - loss: 4.3646e-04 - val_loss: 4.7207e-04 - 17s/epoch - 2ms/step
# Epoch 35/50
# 7245/7245 - 17s - loss: 4.3675e-04 - val_loss: 5.4270e-04 - 17s/epoch - 2ms/step
# Epoch 36/50
# 7245/7245 - 17s - loss: 4.3296e-04 - val_loss: 4.8270e-04 - 17s/epoch - 2ms/step
# Epoch 37/50
# 7245/7245 - 17s - loss: 4.3386e-04 - val_loss: 5.9546e-04 - 17s/epoch - 2ms/step
# Epoch 38/50
# 7245/7245 - 18s - loss: 4.3095e-04 - val_loss: 5.4546e-04 - 18s/epoch - 2ms/step
# Epoch 39/50
# 7245/7245 - 17s - loss: 4.2808e-04 - val_loss: 4.4897e-04 - 17s/epoch - 2ms/step
# Epoch 40/50
# 7245/7245 - 17s - loss: 4.2532e-04 - val_loss: 5.2372e-04 - 17s/epoch - 2ms/step
# Epoch 41/50
# 7245/7245 - 17s - loss: 4.2285e-04 - val_loss: 4.6703e-04 - 17s/epoch - 2ms/step
# Epoch 42/50
# 7245/7245 - 17s - loss: 4.1711e-04 - val_loss: 5.6318e-04 - 17s/epoch - 2ms/step
# Epoch 43/50
# 7245/7245 - 17s - loss: 4.1341e-04 - val_loss: 5.2961e-04 - 17s/epoch - 2ms/step
# Epoch 44/50
# 7245/7245 - 17s - loss: 4.1828e-04 - val_loss: 5.3773e-04 - 17s/epoch - 2ms/step
# Epoch 45/50
# 7245/7245 - 17s - loss: 4.1699e-04 - val_loss: 5.2039e-04 - 17s/epoch - 2ms/step
# Epoch 46/50
# 7245/7245 - 17s - loss: 4.1281e-04 - val_loss: 4.6531e-04 - 17s/epoch - 2ms/step
# Epoch 47/50
# 7245/7245 - 17s - loss: 4.1684e-04 - val_loss: 4.7694e-04 - 17s/epoch - 2ms/step
# Epoch 48/50
# 7245/7245 - 17s - loss: 4.0867e-04 - val_loss: 4.7910e-04 - 17s/epoch - 2ms/step
# Epoch 49/50
# 7245/7245 - 17s - loss: 4.0914e-04 - val_loss: 5.0100e-04 - 17s/epoch - 2ms/step
# Epoch 50/50
# 7245/7245 - 17s - loss: 4.0610e-04 - val_loss: 4.9614e-04 - 17s/epoch - 2ms/step

# %%
# define an encoder model (without the decoder)
encoder = Model(inputs=input_data_shape, outputs=bottleneck)
# save the encoder to file
encoder.save('encoder.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
encoder = load_model('encoder.h5')
encoder.summary()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "model_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 120)]             0
#
#  dense_38 (Dense)            (None, 120)               14520
#
#  batch_normalization_28 (Bat  (None, 120)              480
#  chNormalization)
#
#  leaky_re_lu_28 (LeakyReLU)  (None, 120)               0
#
#  dense_39 (Dense)            (None, 60)                7260
#
#  batch_normalization_29 (Bat  (None, 60)               240
#  chNormalization)
#
#  leaky_re_lu_29 (LeakyReLU)  (None, 60)                0
#
#  dense_40 (Dense)            (None, 30)                1830
#
#  batch_normalization_30 (Bat  (None, 30)               120
#  chNormalization)
#
#  leaky_re_lu_30 (LeakyReLU)  (None, 30)                0
#
#  dense_41 (Dense)            (None, 6)                 186
#
# =================================================================
# Total params: 24,636
# Trainable params: 24,216
# Non-trainable params: 420
# _________________________________________________________________

# %%
X_encode = encoder.predict(X)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt


 
# initialise kmeans
kmeans = KMeans(n_clusters=8)
kmeans.fit(X_encode)
cluster_labels = kmeans.labels_

# %%
for i in range(8):
  plt.figure(i);
  plt.plot(ppg_one_beat[cluster_labels == i].values.T,alpha = 0.5);

# %%
df_info["cluster"] = cluster_labels

# %%
df_info
# Out:
#            dia      sys    ID  clsuter
# 0       66.526  123.040     1        6
# 1       65.598  120.990     1        6
# 2       66.135  119.570     1        6
# 3       66.135  122.350     1        4
# 4       67.503  122.750     1        2
# ...        ...      ...   ...      ...
# 154535  58.357   88.240  3000        5
# 154536  58.983   88.240  3000        5
# 154537  58.670   86.988  3000        5
# 154538  58.044   88.866  3000        5
# 154539  57.731   88.866  3000        5
#
# [154540 rows x 4 columns]

# %%
sns.boxplot(x = "clsuter",y="sys",data = df_info)

# %%
sns.boxplot(x = "clsuter",y="dia",data = df_info)
